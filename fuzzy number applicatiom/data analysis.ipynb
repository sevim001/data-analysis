# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#     height and weight difference  fiber intake  regular sleep  eating speed  \
# 0                            -14             5              1             1
# 1                            -10             5              3             2
# 2                             -5             5              2             1
# 3                             -3             4              2             2
# 4                             -1             4              1             2
# 5                              0             3              3             2
# 6                              1             4              2             3
# 7                              1             4              3             3
# 8                              2             3              3             4
# 9                              2             3              3             3
# 10                             2             3              4             3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   height and weight difference  40 non-null     int64
#  1   fiber intake                  40 non-null     int64
#  2   regular sleep                 40 non-null     int64
#  3   eating speed                  40 non-null     int64
#  4   physical problem              40 non-null     int64
#  5   genetics                      40 non-null     int64
#  6   emotional eating              40 non-null     int64
# dtypes: int64(7)
# memory usage: 2.3 KB

# %%
data.describe()
# Out:
#        height and weight difference  fiber intake  regular sleep  \
# count                     40.000000     40.000000       40.00000
# mean                       8.450000      3.025000        2.92500
# std                       10.810607      1.049725        1.04728
# min                      -14.000000      1.000000        1.00000
# 25%                        2.000000      2.000000        2.00000
# 50%                        7.500000      3.000000        3.00000
# 75%                       13.000000      4.000000        3.25000
# max                       40.000000      5.000000        5.00000
#
#        eating speed  physical problem   genetics  emotional eating
# count      40.00000         40.000000  40.000000         40.000000
# mean        3.12500          2.475000   3.025000          2.675000
# std         0.96576          1.109111   1.187272          1.095152
# min         1.00000          1.000000   1.000000          1.000000
# ...

# %%
data.plot("height and weight difference","fiber intake")
# Out:
# <Axes: xlabel='height and weight difference'>

# %%
data.plot("height and weight difference","regular sleep")
# Out:
# <Axes: xlabel='height and weight difference'>

# %%
data.plot("height and weight difference","eating speed")
# Out:
# <Axes: xlabel='height and weight difference'>

# %%
data.plot("height and weight difference","physical problem")
# Out:
# <Axes: xlabel='height and weight difference'>

# %%
data.plot("height and weight difference","genetics")
# Out:
# <Axes: xlabel='height and weight difference'>

# %%
data.plot("height and weight difference","emotional eating")
# Out:
# <Axes: xlabel='height and weight difference'>
